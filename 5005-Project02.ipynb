# %% [markdown]
# # Project 02

# %% [markdown]
# ## Import helpers
#
# Run the following $2$ cells to download and import helper functions, files and libraries.
#
# You might not need them, but they're here just in case.

# %%
# !wget -q https://github.com/PSAM-5005-2026S-A/5005-utils/raw/main/src/audio_utils.py
# !wget -q https://github.com/PSAM-5005-2026S-A/5005-utils/raw/main/src/data_utils.py
# !wget -q https://github.com/PSAM-5005-2026S-A/5005-utils/raw/main/src/image_utils.py

# %%
import pandas as pd
import matplotlib.pyplot as plt

from data_utils import image_from_url, list_from_csv_url, object_from_json_url

# %% [markdown]
# ## Milestone 02
#
# Start bringing data into your project here

# %% [markdown]
# -> the code i used to parse through the zillow csv

# %%
import csv

csvfile=open("homeprices.csv")
csvfile2=open("SB.csv")
csvreader=csv.reader(csvfile)
csvreader2=csv.reader(csvfile2)
homePrices=list(csvreader)
SBrklyn=list(csvreader2)

import pandas as pd
import matplotlib.pyplot as plt


NYNeighborhoods=[]
for i in homePrices[1:]:
    if i[4]=='NY' and i[5] == 'NY' and i[6]=='New York' and i[8] == 'Kings County' :
        NYNeighborhoods.append(i)


df = pd.read_csv('SB.csv')

meta_cols = ['RegionName', 'RegionType', 'StateName', 'State', 'City', 'CountyName']
date_cols = [c for c in df.columns if c not in meta_cols]

for _, row in df.iterrows():
    plt.plot(date_cols, row[date_cols].values, label=row['RegionName'])

plt.title('NY Neighborhood Home Prices')
plt.xlabel('Date')
plt.ylabel('ZHVI ($)')
plt.xticks(date_cols[::24], rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Milestone 03
#
# Continue pulling and organizing data here

# %% [markdown]
# # Conclusion #
#
#   Since my MS2 project was somewhat data-driven, I decided to double up. For the previous project in this class, I used one of the suggested data sources (instagram), and that was really fun and eye-opening, but getting a feel of how to look for datasets outside of provided resources was really formative. (I looked through some governmental data, as well as forum-boards etc. on ways to look for the type of data that I wanted). After attending the MS Data thesis presentation, it also made me wonder whether these projects and mine are guided by the data available or theme first. In my case, it was the latter but I would've probably had to pivot if I didn't find the data that I did.
#
#   The dataset (csv) I found wasn't too difficult to parse through nor to clean up, in fact, it was much tidier than the instagram one from before. I used knowledge learned from this class to clean it up and translate it into a legible format for myself but did rely on AI for the visualization aspect to keep it aesthetically in line with my MS2 webpage.
#
#   On that note though, since I'm kind of "collecting" data on my MS2 website, if I had the time or if/when I take this project further for thesis, I'd like to be able to store that data into a list. I was particularly inspired by a reading I did in another one of my electives, on how self-enumeration could lead to deep democratic engagement amongst marginalized groups (Appadurai's Deep Democracy) and that's an idea I'd really like to explore.
